# %% [markdown]
# ## Проверка csv

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
observations = pd.read_csv('data/csv/observations-662855.csv')

# %%
observations.head(5)
# Out:
#         id                                  uuid  \
# 0   901916  2e5839c6-8da1-4965-93d9-e7ee2a903940
# 1   901917  771f3c09-205d-4aaf-9b1a-aa1951980bd4
# 2  1464642  1323a647-c68a-43e5-a231-8b7180a3fa02
# 3  1464645  882ce569-f948-4654-b050-dd6c913110ea
# 4  2154726  f5d6b5dd-d2da-4f64-9197-89cd791fea29
#
#                                observed_on_string observed_on  \
# 0  vie jul 18 2014 11:59:02 a.m. GMT-0500 (GMT-5)  2014-07-18
# 1  vie jul 18 2014 11:58:48 a.m. GMT-0500 (GMT-5)  2014-07-18
# 2                             2015-05-03 18:46:23  2015-05-03
# 3                             2015-05-03 18:49:24  2015-05-03
# 4       Wed Oct 14 2015 11:28:58 GMT+0300 (GMT+3)  2015-10-14
#
#             time_observed_at time_zone  user_id user_login  \
# 0  2014-07-18 16:59:02 +0000    Bogota    51810  anapauagr
# 1  2014-07-18 16:58:48 +0000    Bogota    51810  anapauagr
# 2  2015-05-03 15:46:23 +0000    Moscow     2411    dration
# ...
